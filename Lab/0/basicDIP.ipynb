# %%
from PIL import Image
import matplotlib.pyplot as plt

I = Image.open('Lena512Gray.bmp')
plt.figure(1)
plt.subplot(2,2,1)
plt.imshow(I)
plt.subplot(2,2,2)
plt.imshow(I, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
I_2 = Image.open('Lena.bmp')
plt.figure(2)
plt.imshow(I_2)
plt.show()
